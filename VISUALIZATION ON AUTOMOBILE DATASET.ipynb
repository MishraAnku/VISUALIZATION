# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     import seaborn as sns
#     sns.set(color_codes=True)
#
# In \[2\]:
#
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#
# In \[3\]:
#
#     auto=pd.read_csv("Automobile_data.csv")
#
# In \[4\]:
#
#     auto.head()
#
# Out\[4\]:
#
# |     | symboling | normalized-losses | make        | fuel-type | aspiration | num-of-doors | body-style  | drive-wheels | engine-location | wheel-base | ... | engine-size | fuel-system | bore | stroke | compression-ratio | horsepower | peak-rpm | city-mpg | highway-mpg | price |
# |-----|-----------|-------------------|-------------|-----------|------------|--------------|-------------|--------------|-----------------|------------|-----|-------------|-------------|------|--------|-------------------|------------|----------|----------|-------------|-------|
# | 0   | 3         | ?                 | alfa-romero | gas       | std        | two          | convertible | rwd          | front           | 88.6       | ... | 130         | mpfi        | 3.47 | 2.68   | 9.0               | 111        | 5000     | 21       | 27          | 13495 |
# | 1   | 3         | ?                 | alfa-romero | gas       | std        | two          | convertible | rwd          | front           | 88.6       | ... | 130         | mpfi        | 3.47 | 2.68   | 9.0               | 111        | 5000     | 21       | 27          | 16500 |
# | 2   | 1         | ?                 | alfa-romero | gas       | std        | two          | hatchback   | rwd          | front           | 94.5       | ... | 152         | mpfi        | 2.68 | 3.47   | 9.0               | 154        | 5000     | 19       | 26          | 16500 |
# | 3   | 2         | 164               | audi        | gas       | std        | four         | sedan       | fwd          | front           | 99.8       | ... | 109         | mpfi        | 3.19 | 3.4    | 10.0              | 102        | 5500     | 24       | 30          | 13950 |
# | 4   | 2         | 164               | audi        | gas       | std        | four         | sedan       | 4wd          | front           | 99.4       | ... | 136         | mpfi        | 3.19 | 3.4    | 8.0               | 115        | 5500     | 18       | 22          | 17450 |
#
# 5 rows × 26 columns
#
# In \[5\]:
#
#     auto.tail()
#
# Out\[5\]:
#
# |     | symboling | normalized-losses | make  | fuel-type | aspiration | num-of-doors | body-style | drive-wheels | engine-location | wheel-base | ... | engine-size | fuel-system | bore | stroke | compression-ratio | horsepower | peak-rpm | city-mpg | highway-mpg | price |
# |-----|-----------|-------------------|-------|-----------|------------|--------------|------------|--------------|-----------------|------------|-----|-------------|-------------|------|--------|-------------------|------------|----------|----------|-------------|-------|
# | 200 | -1        | 95                | volvo | gas       | std        | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 9.5               | 114        | 5400     | 23       | 28          | 16845 |
# | 201 | -1        | 95                | volvo | gas       | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 8.7               | 160        | 5300     | 19       | 25          | 19045 |
# | 202 | -1        | 95                | volvo | gas       | std        | four         | sedan      | rwd          | front           | 109.1      | ... | 173         | mpfi        | 3.58 | 2.87   | 8.8               | 134        | 5500     | 18       | 23          | 21485 |
# | 203 | -1        | 95                | volvo | diesel    | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 145         | idi         | 3.01 | 3.4    | 23.0              | 106        | 4800     | 26       | 27          | 22470 |
# | 204 | -1        | 95                | volvo | gas       | turbo      | four         | sedan      | rwd          | front           | 109.1      | ... | 141         | mpfi        | 3.78 | 3.15   | 9.5               | 114        | 5400     | 19       | 25          | 22625 |
#
# 5 rows × 26 columns
#
# In \[6\]:
#
#     auto.describe
#
# Out\[6\]:
#
#     <bound method NDFrame.describe of      symboling normalized-losses         make fuel-type aspiration  \
#     0            3                 ?  alfa-romero       gas        std
#     1            3                 ?  alfa-romero       gas        std
#     2            1                 ?  alfa-romero       gas        std
#     3            2               164         audi       gas        std
#     4            2               164         audi       gas        std
#     ..         ...               ...          ...       ...        ...
#     200         -1                95        volvo       gas        std
#     201         -1                95        volvo       gas      turbo
#     202         -1                95        volvo       gas        std
#     203         -1                95        volvo    diesel      turbo
#     204         -1                95        volvo       gas      turbo
#
#         num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
#     0            two  convertible          rwd           front        88.6  ...
#     1            two  convertible          rwd           front        88.6  ...
#     2            two    hatchback          rwd           front        94.5  ...
#     3           four        sedan          fwd           front        99.8  ...
#     4           four        sedan          4wd           front        99.4  ...
#     ..           ...          ...          ...             ...         ...  ...
#     200         four        sedan          rwd           front       109.1  ...
#     201         four        sedan          rwd           front       109.1  ...
#     202         four        sedan          rwd           front       109.1  ...
#     203         four        sedan          rwd           front       109.1  ...
#     204         four        sedan          rwd           front       109.1  ...
#
#          engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     0            130         mpfi  3.47    2.68               9.0        111
#     1            130         mpfi  3.47    2.68               9.0        111
#     2            152         mpfi  2.68    3.47               9.0        154
#     3            109         mpfi  3.19     3.4              10.0        102
#     4            136         mpfi  3.19     3.4               8.0        115
#     ..           ...          ...   ...     ...               ...        ...
#     200          141         mpfi  3.78    3.15               9.5        114
#     201          141         mpfi  3.78    3.15               8.7        160
#     202          173         mpfi  3.58    2.87               8.8        134
#     203          145          idi  3.01     3.4              23.0        106
#     204          141         mpfi  3.78    3.15               9.5        114
#
#          peak-rpm city-mpg highway-mpg  price
#     0        5000       21          27  13495
#     1        5000       21          27  16500
#     2        5000       19          26  16500
#     3        5500       24          30  13950
#     4        5500       18          22  17450
#     ..        ...      ...         ...    ...
#     200      5400       23          28  16845
#     201      5300       19          25  19045
#     202      5500       18          23  21485
#     203      4800       26          27  22470
#     204      5400       19          25  22625
#
#     [205 rows x 26 columns]>
#
# In \[7\]:
#
#     auto.info
#
# Out\[7\]:
#
#     <bound method DataFrame.info of      symboling normalized-losses         make fuel-type aspiration  \
#     0            3                 ?  alfa-romero       gas        std
#     1            3                 ?  alfa-romero       gas        std
#     2            1                 ?  alfa-romero       gas        std
#     3            2               164         audi       gas        std
#     4            2               164         audi       gas        std
#     ..         ...               ...          ...       ...        ...
#     200         -1                95        volvo       gas        std
#     201         -1                95        volvo       gas      turbo
#     202         -1                95        volvo       gas        std
#     203         -1                95        volvo    diesel      turbo
#     204         -1                95        volvo       gas      turbo
#
#         num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
#     0            two  convertible          rwd           front        88.6  ...
#     1            two  convertible          rwd           front        88.6  ...
#     2            two    hatchback          rwd           front        94.5  ...
#     3           four        sedan          fwd           front        99.8  ...
#     4           four        sedan          4wd           front        99.4  ...
#     ..           ...          ...          ...             ...         ...  ...
#     200         four        sedan          rwd           front       109.1  ...
#     201         four        sedan          rwd           front       109.1  ...
#     202         four        sedan          rwd           front       109.1  ...
#     203         four        sedan          rwd           front       109.1  ...
#     204         four        sedan          rwd           front       109.1  ...
#
#          engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
#     0            130         mpfi  3.47    2.68               9.0        111
#     1            130         mpfi  3.47    2.68               9.0        111
#     2            152         mpfi  2.68    3.47               9.0        154
#     3            109         mpfi  3.19     3.4              10.0        102
#     4            136         mpfi  3.19     3.4               8.0        115
#     ..           ...          ...   ...     ...               ...        ...
#     200          141         mpfi  3.78    3.15               9.5        114
#     201          141         mpfi  3.78    3.15               8.7        160
#     202          173         mpfi  3.58    2.87               8.8        134
#     203          145          idi  3.01     3.4              23.0        106
#     204          141         mpfi  3.78    3.15               9.5        114
#
#          peak-rpm city-mpg highway-mpg  price
#     0        5000       21          27  13495
#     1        5000       21          27  16500
#     2        5000       19          26  16500
#     3        5500       24          30  13950
#     4        5500       18          22  17450
#     ..        ...      ...         ...    ...
#     200      5400       23          28  16845
#     201      5300       19          25  19045
#     202      5500       18          23  21485
#     203      4800       26          27  22470
#     204      5400       19          25  22625
#
#     [205 rows x 26 columns]>
#
# In \[8\]:
#
#     auto.shape
#
# Out\[8\]:
#
#     (205, 26)
#
# In \[9\]:
#
#     auto.size
#
# Out\[9\]:
#
#     5330
#
# In \[10\]:
#
#     auto.columns
#
# Out\[10\]:
#
#     Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#            'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#            'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#            'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#            'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#            'highway-mpg', 'price'],
#           dtype='object')
#
# In \[11\]:
#
#     # Pairplot: Shows pairwise relationships in the dataset
#     sns.pairplot(auto)
#     plt.show()
#
#     C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#       self._figure.tight_layout(*args, **kwargs)
#
# ![](data:image/png;base64,...)
#
# In \[14\]:
#
#     # Boxplot: Visualize the distribution of numerical variables
#     sns.boxplot(data=auto[['engine-size', 'horsepower', 'curb-weight', 'price']])
#     plt.title('Boxplot of Numerical Variables')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[15\]:
#
#     # Countplot: Visualize the frequency of categorical variables
#     sns.countplot(data=auto, x='make')
#     plt.xticks(rotation=90)
#     plt.title('Count of Cars by Make')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[16\]:
#
#     sns.distplot(auto["compression-ratio"])
#     plt.show()
#
#     C:\Users\Amrendra Mishra\AppData\Local\Temp\ipykernel_6056\3392564023.py:1: UserWarning:
#
#     `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
#     Please adapt your code to use either `displot` (a figure-level function with
#     similar flexibility) or `histplot` (an axes-level function for histograms).
#
#     For a guide to updating your code to use the new functions, please see
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#       sns.distplot(auto["compression-ratio"])
#
# ![](data:image/png;base64,...)
#
# In \[17\]:
#
#     sns.distplot(auto["city-mpg"])
#     plt.show()
#
#     C:\Users\Amrendra Mishra\AppData\Local\Temp\ipykernel_6056\4195047634.py:1: UserWarning:
#
#     `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
#     Please adapt your code to use either `displot` (a figure-level function with
#     similar flexibility) or `histplot` (an axes-level function for histograms).
#
#     For a guide to updating your code to use the new functions, please see
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#       sns.distplot(auto["city-mpg"])
#
# ![](data:image/png;base64,...)
#
# In \[18\]:
#
#     sns.distplot(auto["city-mpg"],kde=False , rug=True)
#     plt.show()
#
#     C:\Users\Amrendra Mishra\AppData\Local\Temp\ipykernel_6056\1751655890.py:1: UserWarning:
#
#     `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
#     Please adapt your code to use either `displot` (a figure-level function with
#     similar flexibility) or `histplot` (an axes-level function for histograms).
#
#     For a guide to updating your code to use the new functions, please see
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#       sns.distplot(auto["city-mpg"],kde=False , rug=True)
#
# ![](data:image/png;base64,...)
#
# In \[19\]:
#
#     sns.distplot(auto["engine-size"],kde=False , rug=True)
#     plt.show()
#
#     C:\Users\Amrendra Mishra\AppData\Local\Temp\ipykernel_6056\3073592937.py:1: UserWarning:
#
#     `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
#     Please adapt your code to use either `displot` (a figure-level function with
#     similar flexibility) or `histplot` (an axes-level function for histograms).
#
#     For a guide to updating your code to use the new functions, please see
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#       sns.distplot(auto["engine-size"],kde=False , rug=True)
#
# ![](data:image/png;base64,...)
#
# In \[20\]:
#
#     sns.jointplot((auto['engine-size'],auto['horsepower']))
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[21\]:
#
#     sns.pairplot(auto[['normalized-losses','engine-size','horsepower']])
#     plt.show
#
#     C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#       self._figure.tight_layout(*args, **kwargs)
#
# Out\[21\]:
#
#     <function matplotlib.pyplot.show(close=None, block=None)>
#
# ![](data:image/png;base64,...)
#
# In \[22\]:
#
#     sns.stripplot(auto[['fuel-type','horsepower']])
#     plt.show
#
# Out\[22\]:
#
#     <function matplotlib.pyplot.show(close=None, block=None)>
#
# ![](data:image/png;base64,...)
#
# In \[23\]:
#
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#     import pandas as pd
#
# In \[24\]:
#
#     # Jointplot: Scatterplot with marginal histograms
#     sns.jointplot(x='engine-size', y='horsepower', data=auto, kind='scatter')
#     plt.title('Jointplot: Engine Size vs Horsepower')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[27\]:
#
#     # Pairplot: Pairwise scatterplot of numerical variables
#     sns.pairplot(auto[['engine-size', 'horsepower', 'curb-weight', 'price']])
#     plt.title('Pairplot of Numerical Variables')
#     plt.show()
#
#     C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#       self._figure.tight_layout(*args, **kwargs)
#
# ![](data:image/png;base64,...)
#
# In \[28\]:
#
#     # Stripplot: Scatterplot of categorical vs numerical variables
#     sns.stripplot(x='make', y='horsepower', data=auto)
#     plt.xticks(rotation=90)
#     plt.title('Stripplot: Make vs Horsepower')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[29\]:
#
#     # Swarmplot: Similar to stripplot, but points are adjusted to avoid overlap
#     sns.swarmplot(x='fuel-type', y='horsepower', data=auto)
#     plt.title('Swarmplot: Fuel Type vs Horsepower')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[30\]:
#
#     # Boxplot: Visualize the distribution of numerical variables
#     sns.boxplot(data=auto[['engine-size', 'horsepower', 'curb-weight', 'price']])
#     plt.title('Boxplot of Numerical Variables')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[32\]:
#
#     # Countplot: Visualize the frequency of categorical variables
#     sns.countplot(data=auto, x='make')
#     plt.xticks(rotation=90)
#     plt.title('Countplot: Make')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
